# %%
# League of Legends Game State Analyzer with YOLO Label Generation
import cv2
import pytesseract
import os
import time
import numpy as np
from PIL import Image
import pandas as pd

# Configuration
OUTPUT_DIR = "extracted_frames_MR"
MAX_PROCESSING_SECONDS = 600  # 10 minutes
VIDEO_PATH = "videos/MR.mp4"
ANALYSIS_INTERVAL = 1  # Seconds between frames
OUTPUT_IMAGES = True  # Set False to disable image saving

# Region of Interest Configurations (1920x1080 resolution)
UI_CONFIG = {
    "gold": {
        "roi": (1170, 1045, 70, 30),
        "threshold": 180,
        "digits": 4
    },
    "minions": {
        "roi": (1775, 0, 40, 30),
        "threshold": 190,
        "digits": 3
    },
    "skills": {
        "Q": (730, 950, 60, 60),
        "W": (795, 950, 60, 60),
        "E": (860, 950, 60, 60),
        "R": (925, 950, 60, 60)
    }
}

# Cooldown detection parameters
BLUE_HSV_LOWER = np.array([90, 50, 50], dtype=np.uint8)
BLUE_HSV_UPPER = np.array([120, 255, 255], dtype=np.uint8)
CD_THRESHOLD = 0.2

# Skill output directories
SKILL_DIRS = {
    'Q': "q_cd",
    'W': "w_cd",
    'E': "e_cd",
    'R': "r_cd"
}

# Tesseract Setup (Windows)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def create_yolo_labels(skill_img):
    """Generate YOLO format labels for detected digits"""
    # Convert to grayscale and threshold
    gray = cv2.cvtColor(skill_img, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    
    # Find contours of potential digits
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    labels = []
    
    for cnt in contours:
        x, y, w, h = cv2.boundingRect(cnt)
        if w*h > 100:  # Filter small noise
            # Convert to YOLO format (normalized coordinates)
            x_center = (x + w/2) / skill_img.shape[1]
            y_center = (y + h/2) / skill_img.shape[0]
            width = w / skill_img.shape[1]
            height = h / skill_img.shape[0]
            
            labels.append(f"0 {x_center:.4f} {y_center:.4f} {width:.4f} {height:.4f}")
    
    return labels

def preprocess_image(roi):
    """Enhanced image optimization pipeline"""
    gray = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
    clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
    enhanced = clahe.apply(gray)
    _, thresh = cv2.threshold(enhanced, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return thresh

def extract_digits(processed_img, config):
    """OCR execution with validation"""
    custom_config = f'--psm 6 --oem 3 -c tessedit_char_whitelist=0123456789'
    try:
        text = pytesseract.image_to_string(Image.fromarray(processed_img), config=custom_config)
        filtered = ''.join(filter(str.isdigit, text)).lstrip('0')
        return filtered.zfill(config["digits"]) if filtered else '0'*config["digits"]
    except Exception as e:
        print(f"OCR Error: {str(e)}")
        return 'NULL'

def detect_cooldown(skill_roi):
    """Detect cooldown state using original image for OCR"""
    hsv = cv2.cvtColor(skill_roi, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, BLUE_HSV_LOWER, BLUE_HSV_UPPER)
    coverage = np.sum(mask > 0) / (skill_roi.size / 3)
    
    if coverage > CD_THRESHOLD:
        # Convert to RGB for Tesseract
        skill_roi_rgb = cv2.cvtColor(skill_roi, cv2.COLOR_BGR2RGB)
        
        # OCR on original image
        text = pytesseract.image_to_string(
            skill_roi_rgb,
            config='--psm 7 --oem 3 -c tessedit_char_whitelist=0123456789'
        )
        digits = ''.join(filter(str.isdigit, text))
        return digits or "CD", skill_roi
    
    return "Ready", None

def process_frame(frame, frame_count, video_time_ms):
    """Complete frame processing workflow with video timestamp"""
    # Convert milliseconds to HH:MM:SS.mmm format
    hours, ms_remaining = divmod(video_time_ms, 3600000)
    minutes, ms_remaining = divmod(ms_remaining, 60000)
    seconds, milliseconds = divmod(ms_remaining, 1000)
    timestamp = f"{int(hours):02d}:{int(minutes):02d}:{int(seconds):02d}.{int(milliseconds):03d}"
    
    frame_dir = os.path.join(OUTPUT_DIR, f"frame_{frame_count}")
    marked_frame = frame.copy()
    results = {}
    
    if OUTPUT_IMAGES:
        os.makedirs(frame_dir, exist_ok=True)
        cv2.imwrite(os.path.join(frame_dir, "original.jpg"), frame)

    # Process gold and minions
    for element in ["gold", "minions"]:
        cfg = UI_CONFIG[element]
        x, y, w, h = cfg["roi"]
        roi = frame[y:y+h, x:x+w]
        
        processed = preprocess_image(roi)
        results[element] = extract_digits(processed, cfg)
        
        if OUTPUT_IMAGES:
            cv2.imwrite(os.path.join(frame_dir, f"{element}_processed.jpg"), processed)
            cv2.rectangle(marked_frame, (x, y), (x+w, y+h), (0, 0, 255), 2)

    # Process skills and save training data
    skill_results = {}
    for skill, roi in UI_CONFIG["skills"].items():
        x, y, w, h = roi
        skill_roi = frame[y:y+h, x:x+w]
        
        cd_state, processed_img = detect_cooldown(skill_roi)
        skill_results[skill] = cd_state
        
        # Visualization
        color = (255, 0, 0) if cd_state not in ["Ready"] else (0, 255, 0)
        cv2.rectangle(marked_frame, (x, y), (x+w, y+h), color, 2)
        cv2.putText(marked_frame, cd_state, (x+5, y+20), 
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 1)
        
        # Save training data for YOLO
        if cd_state not in ["Ready"] and OUTPUT_IMAGES and processed_img is not None:
            skill_dir = os.path.join(OUTPUT_DIR, SKILL_DIRS[skill])
            os.makedirs(skill_dir, exist_ok=True)
            
            # Save image
            img_name = f"{timestamp.replace(':', '-')}_{skill}.jpg"
            img_path = os.path.join(skill_dir, img_name)
            cv2.imwrite(img_path, processed_img)
            
            # Generate and save labels
            labels = create_yolo_labels(processed_img)
            label_path = os.path.join(skill_dir, img_name.replace('.jpg', '.txt'))
            with open(label_path, 'w') as f:
                f.write('\n'.join(labels))

    if OUTPUT_IMAGES:
        cv2.imwrite(os.path.join(frame_dir, "marked.jpg"), marked_frame)

    return {
        "video_timestamp": timestamp,
        **results,
        **skill_results,
        "frame_path": frame_dir
    }

def video_processing():
    """Main processing loop with time constraint"""
    start_time = time.time()
    cap = cv2.VideoCapture(VIDEO_PATH)
    fps = cap.get(cv2.CAP_PROP_FPS)
    frame_interval = int(fps * ANALYSIS_INTERVAL)
    
    dataset = []
    frame_count = 0
    
    # Create output directories
    for skill_dir in SKILL_DIRS.values():
        os.makedirs(os.path.join(OUTPUT_DIR, skill_dir), exist_ok=True)
    
    while cap.isOpened() and (time.time() - start_time) <= MAX_PROCESSING_SECONDS:
        ret, frame = cap.read()
        if not ret: break
        
        current_time_ms = cap.get(cv2.CAP_PROP_POS_MSEC)
        
        if frame_count % frame_interval == 0:
            frame_data = process_frame(frame, frame_count, current_time_ms)
            log_entry = (f"Video Time: {frame_data['video_timestamp']} | "
                        f"Gold: {frame_data['gold']} | "
                        f"Minions: {frame_data['minions']} | "
                        f"Q: {frame_data['Q']} | "
                        f"W: {frame_data['W']} | "
                        f"E: {frame_data['E']} | "
                        f"R: {frame_data['R']}")
            print(log_entry)
            dataset.append(frame_data)
        
        frame_count += 1
    
    pd.DataFrame(dataset).to_csv(os.path.join(OUTPUT_DIR, "analysis_report.csv"), index=False)
    cap.release()
    print(f"Processing completed. Results saved to {OUTPUT_DIR}")

if __name__ == "__main__":
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    video_processing()
# Out:
# Video Time: 00:00:00.000 | Gold: 0500 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:00.920 | Gold: 0500 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:01.960 | Gold: 0500 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:02.961 | Gold: 0500 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:03.934 | Gold: 0500 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:04.921 | Gold: 0500 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:05.935 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:06.949 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:07.922 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:08.923 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:09.910 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:10.937 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:11.910 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:12.884 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:13.871 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:14.872 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:15.845 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:16.832 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:17.819 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:18.833 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:19.847 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:20.834 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:21.821 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:22.808 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:23.821 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:24.808 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:25.782 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:26.769 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:27.770 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:28.743 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:29.744 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:30.744 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:31.718 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:32.705 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:33.705 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:34.705 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:35.679 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:36.666 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:37.666 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:38.667 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:39.641 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:40.641 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:41.615 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:42.615 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:43.655 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:44.682 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:45.669 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:46.656 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:47.670 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:48.657 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:49.684 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:50.698 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:51.685 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:52.659 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:53.646 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:54.659 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:55.620 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:56.647 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:57.674 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:58.661 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:00:59.661 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:00.675 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:01.702 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:02.662 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:03.703 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:04.690 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:05.717 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:06.730 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:07.717 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:08.718 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:09.758 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:10.758 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:11.732 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:12.732 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:13.719 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:14.720 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:15.707 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:16.747 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:17.748 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:18.761 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:19.748 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:20.722 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:21.696 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:22.696 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:23.670 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:24.670 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:25.657 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:26.671 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:27.658 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:28.645 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:29.619 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:30.646 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:31.659 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:32.660 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:33.647 | Gold: 0000 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:34.647 | Gold: 0001 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:35.701 | Gold: 0003 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:36.701 | Gold: 0005 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:37.702 | Gold: 0007 | Minions: 000 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:38.689 | Gold: 0009 | Minions: 000 | Q: 7 | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:39.716 | Gold: 4141 | Minions: 000 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:40.729 | Gold: 0013 | Minions: 000 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:41.730 | Gold: 0015 | Minions: 000 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:42.717 | Gold: 0017 | Minions: 000 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:43.744 | Gold: 0019 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:44.731 | Gold: 0021 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:45.718 | Gold: 0023 | Minions: 000 | Q: 8 | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:46.745 | Gold: 0025 | Minions: 000 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:47.732 | Gold: 0027 | Minions: 000 | Q: 6 | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:48.732 | Gold: 0029 | Minions: 000 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:49.719 | Gold: 0031 | Minions: 000 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:50.733 | Gold: 0033 | Minions: 000 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:51.733 | Gold: 0049 | Minions: 001 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:52.667 | Gold: 0051 | Minions: 001 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:53.667 | Gold: 0000 | Minions: 002 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:54.694 | Gold: 0076 | Minions: 002 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:55.641 | Gold: 0078 | Minions: 002 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:56.602 | Gold: 0080 | Minions: 002 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:57.549 | Gold: 0000 | Minions: 003 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:58.509 | Gold: 0097 | Minions: 003 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:01:59.509 | Gold: 0099 | Minions: 003 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:00.496 | Gold: 0102 | Minions: 003 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:01.457 | Gold: 0118 | Minions: 004 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:02.457 | Gold: 0120 | Minions: 004 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:03.444 | Gold: 0122 | Minions: 004 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:04.458 | Gold: 0138 | Minions: 005 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:05.458 | Gold: 0140 | Minions: 005 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:06.525 | Gold: 0142 | Minions: 005 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:07.579 | Gold: 0165 | Minions: 006 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:08.673 | Gold: 0168 | Minions: 006 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:09.686 | Gold: 0191 | Minions: 007 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:10.673 | Gold: 0193 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:11.714 | Gold: 0195 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:12.741 | Gold: 0211 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:13.755 | Gold: 0213 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:14.768 | Gold: 0215 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:15.769 | Gold: 0217 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:16.809 | Gold: 0219 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:17.796 | Gold: 0221 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:18.783 | Gold: 0223 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:19.757 | Gold: 0225 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:20.757 | Gold: 0227 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:21.704 | Gold: 0229 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:22.691 | Gold: 0231 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:23.798 | Gold: 0233 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:24.825 | Gold: 0236 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:25.786 | Gold: 0238 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:26.786 | Gold: 0000 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:27.800 | Gold: 0242 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:28.733 | Gold: 0244 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:29.720 | Gold: 0246 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:30.694 | Gold: 0248 | Minions: 008 | Q: 7 | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:31.694 | Gold: 0250 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:32.655 | Gold: 0252 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:33.655 | Gold: 0254 | Minions: 000 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:34.669 | Gold: 0256 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:35.656 | Gold: 0258 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:36.656 | Gold: 0260 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:37.670 | Gold: 0262 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:38.644 | Gold: 0264 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:39.591 | Gold: 0266 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:40.564 | Gold: 0268 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:41.578 | Gold: 0270 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:42.565 | Gold: 0272 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:43.592 | Gold: 0274 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:44.552 | Gold: 0276 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:45.566 | Gold: 0278 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:46.566 | Gold: 0280 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:47.607 | Gold: 0282 | Minions: 008 | Q: 7 | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:48.620 | Gold: 0284 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:49.608 | Gold: 0287 | Minions: 008 | Q: 7 | W: Ready | E: 3 | R: Ready
# Video Time: 00:02:50.608 | Gold: 2389 | Minions: 008 | Q: CD | W: Ready | E: CD | R: Ready
# Video Time: 00:02:51.648 | Gold: 0291 | Minions: 008 | Q: CD | W: Ready | E: CD | R: Ready
# Video Time: 00:02:52.649 | Gold: 0293 | Minions: 008 | Q: Ready | W: Ready | E: CD | R: Ready
# Video Time: 00:02:53.596 | Gold: 0295 | Minions: 008 | Q: Ready | W: Ready | E: 4 | R: Ready
# Video Time: 00:02:54.569 | Gold: 0296 | Minions: 008 | Q: CD | W: Ready | E: CD | R: Ready
# Video Time: 00:02:55.583 | Gold: 0299 | Minions: 008 | Q: 7 | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:56.677 | Gold: 0301 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:57.664 | Gold: 0003 | Minions: 008 | Q: 7 | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:58.651 | Gold: 0005 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:02:59.678 | Gold: 0007 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:00.678 | Gold: 0023 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:01.719 | Gold: 0041 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:02.719 | Gold: 0013 | Minions: 000 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:03.733 | Gold: 0045 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:04.746 | Gold: 0001 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:05.747 | Gold: 0419 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:06.734 | Gold: 0021 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:07.707 | Gold: 0023 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:08.708 | Gold: 0025 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:09.681 | Gold: 0027 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:10.668 | Gold: 0029 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:11.669 | Gold: 0031 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:12.656 | Gold: 0033 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:13.670 | Gold: 0035 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:14.683 | Gold: 0038 | Minions: 008 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:15.670 | Gold: 0040 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:16.671 | Gold: 0042 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:17.658 | Gold: 0044 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:18.671 | Gold: 0046 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:19.658 | Gold: 0048 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:20.645 | Gold: 0050 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:21.632 | Gold: 0052 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:22.619 | Gold: 0054 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:23.620 | Gold: 0056 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:24.634 | Gold: 0058 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:25.607 | Gold: 0060 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:26.568 | Gold: 0062 | Minions: 008 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:27.595 | Gold: 0064 | Minions: 008 | Q: Ready | W: Ready | E: CD | R: Ready
# Video Time: 00:03:28.608 | Gold: 0080 | Minions: 009 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:29.622 | Gold: 0082 | Minions: 009 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:03:30.636 | Gold: 0112 | Minions: 014 | Q: Ready | W: Ready | E: CD | R: Ready
# Video Time: 00:03:31.609 | Gold: 0114 | Minions: 011 | Q: Ready | W: Ready | E: 8 | R: Ready
# Video Time: 00:03:32.676 | Gold: 0130 | Minions: 012 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:03:33.663 | Gold: 0132 | Minions: 013 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:03:34.650 | Gold: 0148 | Minions: 013 | Q: Ready | W: CD | E: 4 | R: Ready
# Video Time: 00:03:35.637 | Gold: 0150 | Minions: 013 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:03:36.638 | Gold: 0152 | Minions: 013 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:03:37.638 | Gold: 0154 | Minions: 013 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:38.652 | Gold: 0156 | Minions: 013 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:39.666 | Gold: 0173 | Minions: 014 | Q: Ready | W: CD | E: 07 | R: Ready
# Video Time: 00:03:40.653 | Gold: 0175 | Minions: 014 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:41.693 | Gold: 0177 | Minions: 014 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:42.720 | Gold: 0207 | Minions: 016 | Q: Ready | W: CD | E: 3 | R: Ready
# Video Time: 00:03:43.694 | Gold: 0209 | Minions: 016 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:03:44.681 | Gold: 0211 | Minions: 016 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:03:45.708 | Gold: 0213 | Minions: 016 | Q: Ready | W: CD | E: 6 | R: Ready
# Video Time: 00:03:46.721 | Gold: 0215 | Minions: 016 | Q: Ready | W: CD | E: 3 | R: Ready
# Video Time: 00:03:47.735 | Gold: 0217 | Minions: 016 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:03:48.709 | Gold: 0219 | Minions: 016 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:03:49.723 | Gold: 0221 | Minions: 016 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:50.736 | Gold: 0223 | Minions: 016 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:51.790 | Gold: 0225 | Minions: 016 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:52.857 | Gold: 0227 | Minions: 016 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:53.871 | Gold: 0229 | Minions: 016 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:54.858 | Gold: 0231 | Minions: 016 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:55.845 | Gold: 0233 | Minions: 016 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:56.872 | Gold: 0235 | Minions: 016 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:03:57.872 | Gold: 0237 | Minions: 016 | Q: 8 | W: CD | E: CD | R: Ready
# Video Time: 00:03:58.846 | Gold: 0239 | Minions: 016 | Q: CD | W: 2 | E: Ready | R: Ready
# Video Time: 00:03:59.846 | Gold: 0241 | Minions: 016 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:00.847 | Gold: 0243 | Minions: 016 | Q: CD | W: 20 | E: CD | R: Ready
# Video Time: 00:04:01.807 | Gold: 0245 | Minions: 016 | Q: CD | W: 1 | E: 8 | R: Ready
# Video Time: 00:04:02.794 | Gold: 0247 | Minions: 016 | Q: CD | W: CD | E: CD | R: Ready
# Video Time: 00:04:03.808 | Gold: 0249 | Minions: 016 | Q: CD | W: 7 | E: CD | R: Ready
# Video Time: 00:04:04.768 | Gold: 0252 | Minions: 016 | Q: Ready | W: CD | E: 3 | R: Ready
# Video Time: 00:04:05.755 | Gold: 0000 | Minions: 016 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:04:06.769 | Gold: 0256 | Minions: 016 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:04:07.769 | Gold: 0258 | Minions: 016 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:08.796 | Gold: 0260 | Minions: 016 | Q: Ready | W: 3 | E: Ready | R: Ready
# Video Time: 00:04:09.810 | Gold: 0283 | Minions: 017 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:10.810 | Gold: 0299 | Minions: 000 | Q: Ready | W: 10 | E: Ready | R: Ready
# Video Time: 00:04:11.837 | Gold: 0301 | Minions: 018 | Q: Ready | W: 9 | E: Ready | R: Ready
# Video Time: 00:04:12.838 | Gold: 0303 | Minions: 000 | Q: CD | W: 18 | E: Ready | R: Ready
# Video Time: 00:04:13.825 | Gold: 0305 | Minions: 018 | Q: 7 | W: CD | E: Ready | R: Ready
# Video Time: 00:04:14.785 | Gold: 0307 | Minions: 018 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:15.772 | Gold: 0309 | Minions: 018 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:16.799 | Gold: 0436 | Minions: 018 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:17.786 | Gold: 0438 | Minions: 018 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:18.800 | Gold: 0440 | Minions: 018 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:19.827 | Gold: 0442 | Minions: 018 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:04:20.854 | Gold: 0444 | Minions: 018 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:21.881 | Gold: 0446 | Minions: 018 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:22.881 | Gold: 0448 | Minions: 018 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:23.855 | Gold: 0450 | Minions: 018 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:24.855 | Gold: 0452 | Minions: 018 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:25.842 | Gold: 0454 | Minions: 018 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:26.843 | Gold: 0456 | Minions: 018 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:27.816 | Gold: 0453 | Minions: 018 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:28.843 | Gold: 0460 | Minions: 018 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:29.844 | Gold: 0463 | Minions: 018 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:30.884 | Gold: 0465 | Minions: 018 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:31.804 | Gold: 0467 | Minions: 018 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:32.818 | Gold: 0469 | Minions: 018 | Q: 6 | W: CD | E: Ready | R: Ready
# Video Time: 00:04:33.752 | Gold: 0471 | Minions: 018 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:34.739 | Gold: 0473 | Minions: 418 | Q: CD | W: CD | E: 08 | R: Ready
# Video Time: 00:04:35.753 | Gold: 0475 | Minions: 018 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:36.740 | Gold: 0477 | Minions: 018 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:37.740 | Gold: 0500 | Minions: 019 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:04:38.740 | Gold: 0502 | Minions: 019 | Q: Ready | W: CD | E: 8 | R: Ready
# Video Time: 00:04:39.741 | Gold: 0504 | Minions: 019 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:04:40.754 | Gold: 0506 | Minions: 019 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:04:41.728 | Gold: 0508 | Minions: 019 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:04:42.675 | Gold: 0510 | Minions: 019 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:04:43.689 | Gold: 0512 | Minions: 019 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:04:44.649 | Gold: 0580 | Minions: 020 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:45.663 | Gold: 0596 | Minions: 021 | Q: 4 | W: CD | E: Ready | R: Ready
# Video Time: 00:04:46.663 | Gold: 0598 | Minions: 021 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:47.704 | Gold: 0600 | Minions: 021 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:48.731 | Gold: 0602 | Minions: 021 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:49.758 | Gold: 0618 | Minions: 022 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:50.745 | Gold: 0620 | Minions: 022 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:51.732 | Gold: 0622 | Minions: 022 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:52.745 | Gold: 0624 | Minions: 022 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:53.772 | Gold: 0626 | Minions: 022 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:54.759 | Gold: 0629 | Minions: 022 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:55.800 | Gold: 0631 | Minions: 022 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:04:56.827 | Gold: 0633 | Minions: 022 | Q: CD | W: CD | E: CD | R: Ready
# Video Time: 00:04:57.827 | Gold: 0635 | Minions: 022 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:04:58.841 | Gold: 0000 | Minions: 022 | Q: 6 | W: CD | E: Ready | R: Ready
# Video Time: 00:04:59.788 | Gold: 0639 | Minions: 000 | Q: CD | W: 20 | E: CD | R: Ready
# Video Time: 00:05:00.788 | Gold: 0641 | Minions: 000 | Q: CD | W: 7 | E: 4 | R: Ready
# Video Time: 00:05:01.762 | Gold: 0643 | Minions: 022 | Q: CD | W: 18 | E: CD | R: Ready
# Video Time: 00:05:02.776 | Gold: 0645 | Minions: 022 | Q: CD | W: 7 | E: CD | R: Ready
# Video Time: 00:05:03.683 | Gold: 0668 | Minions: 023 | Q: Ready | W: 2 | E: 4 | R: Ready
# Video Time: 00:05:04.656 | Gold: 0691 | Minions: 024 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:05:05.617 | Gold: 0693 | Minions: 024 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:05:06.590 | Gold: 0716 | Minions: 025 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:05:07.604 | Gold: 7138 | Minions: 025 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:08.604 | Gold: 0720 | Minions: 025 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:09.632 | Gold: 0722 | Minions: 025 | Q: Ready | W: 1 | E: Ready | R: Ready
# Video Time: 00:05:10.632 | Gold: 0724 | Minions: 025 | Q: Ready | W: 9 | E: Ready | R: Ready
# Video Time: 00:05:11.646 | Gold: 0740 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:12.646 | Gold: 0742 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:13.633 | Gold: 0744 | Minions: 026 | Q: 6 | W: CD | E: Ready | R: Ready
# Video Time: 00:05:14.620 | Gold: 0746 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:15.634 | Gold: 0748 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:16.661 | Gold: 0750 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:17.648 | Gold: 0877 | Minions: 026 | Q: CD | W: Ready | E: Ready | R: Ready
# Video Time: 00:05:18.648 | Gold: 0879 | Minions: 026 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:05:19.635 | Gold: 0882 | Minions: 026 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:20.635 | Gold: 0884 | Minions: 026 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:21.596 | Gold: 0886 | Minions: 026 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:22.583 | Gold: 0888 | Minions: 026 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:23.570 | Gold: 0890 | Minions: 026 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:24.570 | Gold: 0892 | Minions: 026 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:25.544 | Gold: 0894 | Minions: 026 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:26.544 | Gold: 0896 | Minions: 026 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:27.558 | Gold: 0898 | Minions: 026 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:28.545 | Gold: 0899 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:29.479 | Gold: 0901 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:30.532 | Gold: 0903 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:31.506 | Gold: 0905 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:32.493 | Gold: 0907 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:33.533 | Gold: 0909 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:34.521 | Gold: 0911 | Minions: 026 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:35.548 | Gold: 0934 | Minions: 027 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:36.508 | Gold: 0936 | Minions: 027 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:05:37.468 | Gold: 0938 | Minions: 028 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:05:38.469 | Gold: 0961 | Minions: 028 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:05:39.469 | Gold: 0963 | Minions: 028 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:05:40.509 | Gold: 0979 | Minions: 029 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:05:41.510 | Gold: 0995 | Minions: 030 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:05:42.483 | Gold: 0997 | Minions: 030 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:05:43.457 | Gold: 0999 | Minions: 030 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:44.457 | Gold: 1016 | Minions: 031 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:45.458 | Gold: 1018 | Minions: 003 | Q: 6 | W: CD | E: Ready | R: Ready
# Video Time: 00:05:46.445 | Gold: 1020 | Minions: 003 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:47.445 | Gold: 1022 | Minions: 031 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:48.432 | Gold: 1024 | Minions: 031 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:49.433 | Gold: 1026 | Minions: 003 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:05:50.420 | Gold: 1028 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:51.407 | Gold: 1030 | Minions: 003 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:52.420 | Gold: 1032 | Minions: 003 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:53.394 | Gold: 1034 | Minions: 003 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:54.408 | Gold: 1036 | Minions: 003 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:55.448 | Gold: 1038 | Minions: 000 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:56.475 | Gold: 0340 | Minions: 003 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:57.542 | Gold: 0343 | Minions: 000 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:58.516 | Gold: 0345 | Minions: 000 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:05:59.530 | Gold: 0347 | Minions: 000 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:00.543 | Gold: 0349 | Minions: 000 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:01.530 | Gold: 0000 | Minions: 000 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:02.517 | Gold: 0003 | Minions: 003 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:03.518 | Gold: 0005 | Minions: 003 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:04.545 | Gold: 0007 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:05.505 | Gold: 0003 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:06.465 | Gold: 0010 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:07.479 | Gold: 0012 | Minions: 003 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:06:08.479 | Gold: 0414 | Minions: 031 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:06:09.453 | Gold: 0017 | Minions: 000 | Q: 6 | W: CD | E: Ready | R: Ready
# Video Time: 00:06:10.494 | Gold: 0019 | Minions: 031 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:06:11.547 | Gold: 0022 | Minions: 031 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:06:12.601 | Gold: 0024 | Minions: 003 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:06:13.615 | Gold: 0026 | Minions: 000 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:06:14.602 | Gold: 0028 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:15.602 | Gold: 0030 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:16.629 | Gold: 0032 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:17.616 | Gold: 0034 | Minions: 003 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:18.656 | Gold: 0036 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:19.644 | Gold: 0038 | Minions: 003 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:20.657 | Gold: 0040 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:21.698 | Gold: 0042 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:22.711 | Gold: 0000 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:23.725 | Gold: 0046 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:24.712 | Gold: 0048 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:25.712 | Gold: 0050 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:26.739 | Gold: 0052 | Minions: 031 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:27.833 | Gold: 0054 | Minions: 003 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:06:28.833 | Gold: 0056 | Minions: 003 | Q: CD | W: CD | E: CD | R: Ready
# Video Time: 00:06:29.834 | Gold: 0058 | Minions: 031 | Q: CD | W: 2 | E: Ready | R: Ready
# Video Time: 00:06:30.807 | Gold: 0060 | Minions: 031 | Q: 6 | W: 24 | E: Ready | R: Ready
# Video Time: 00:06:31.808 | Gold: 0362 | Minions: 003 | Q: CD | W: 20 | E: CD | R: CD
# Video Time: 00:06:32.848 | Gold: 0384 | Minions: 031 | Q: CD | W: CD | E: 8 | R: 2
# Video Time: 00:06:33.929 | Gold: 0386 | Minions: 003 | Q: CD | W: 18 | E: CD | R: CD
# Video Time: 00:06:34.956 | Gold: 0389 | Minions: 003 | Q: Ready | W: CD | E: 4 | R: 117
# Video Time: 00:06:35.969 | Gold: 0391 | Minions: 000 | Q: Ready | W: CD | E: CD | R: CD
# Video Time: 00:06:36.943 | Gold: 0393 | Minions: 000 | Q: Ready | W: 18 | E: CD | R: CD
# Video Time: 00:06:37.917 | Gold: 0395 | Minions: 000 | Q: Ready | W: CD | E: CD | R: CD
# Video Time: 00:06:38.944 | Gold: 0397 | Minions: 000 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:06:39.971 | Gold: 0399 | Minions: 003 | Q: Ready | W: CD | E: Ready | R: 2
# Video Time: 00:06:40.998 | Gold: 0416 | Minions: 032 | Q: Ready | W: CD | E: 08 | R: CD
# Video Time: 00:06:42.012 | Gold: 0432 | Minions: 033 | Q: Ready | W: 10 | E: Ready | R: CD
# Video Time: 00:06:43.012 | Gold: 0447 | Minions: 035 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:06:43.972 | Gold: 0477 | Minions: 036 | Q: Ready | W: CD | E: CD | R: 488
# Video Time: 00:06:44.933 | Gold: 0479 | Minions: 036 | Q: Ready | W: CD | E: 8 | R: CD
# Video Time: 00:06:45.933 | Gold: 0481 | Minions: 036 | Q: Ready | W: CD | E: CD | R: 18
# Video Time: 00:06:46.933 | Gold: 0483 | Minions: 036 | Q: Ready | W: CD | E: CD | R: 8
# Video Time: 00:06:47.947 | Gold: 0485 | Minions: 036 | Q: Ready | W: CD | E: CD | R: CD
# Video Time: 00:06:48.934 | Gold: 0487 | Minions: 036 | Q: Ready | W: CD | E: CD | R: 42
# Video Time: 00:06:49.854 | Gold: 0489 | Minions: 036 | Q: Ready | W: Ready | E: CD | R: 42
# Video Time: 00:06:50.828 | Gold: 0491 | Minions: 036 | Q: Ready | W: Ready | E: Ready | R: CD
# Video Time: 00:06:51.802 | Gold: 0493 | Minions: 036 | Q: Ready | W: CD | E: Ready | R: 409
# Video Time: 00:06:52.815 | Gold: 0495 | Minions: 036 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:06:53.816 | Gold: 0497 | Minions: 363 | Q: Ready | W: CD | E: Ready | R: 98
# Video Time: 00:06:54.776 | Gold: 0499 | Minions: 036 | Q: Ready | W: CD | E: Ready | R: 97
# Video Time: 00:06:55.803 | Gold: 0501 | Minions: 036 | Q: Ready | W: CD | E: Ready | R: 96
# Video Time: 00:06:56.817 | Gold: 0503 | Minions: 036 | Q: Ready | W: CD | E: Ready | R: 98
# Video Time: 00:06:57.817 | Gold: 0505 | Minions: 036 | Q: Ready | W: CD | E: Ready | R: 94
# Video Time: 00:06:58.804 | Gold: 5238 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: 98
# Video Time: 00:06:59.805 | Gold: 0531 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:00.765 | Gold: 0533 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:01.779 | Gold: 0535 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:02.752 | Gold: 0537 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: 89
# Video Time: 00:07:03.766 | Gold: 0539 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: 88
# Video Time: 00:07:04.726 | Gold: 0541 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: 87
# Video Time: 00:07:05.687 | Gold: 0543 | Minions: 037 | Q: Ready | W: CD | E: CD | R: 87
# Video Time: 00:07:06.687 | Gold: 0545 | Minions: 037 | Q: Ready | W: CD | E: CD | R: 86
# Video Time: 00:07:07.674 | Gold: 0547 | Minions: 037 | Q: Ready | W: Ready | E: Ready | R: 88
# Video Time: 00:07:08.648 | Gold: 0549 | Minions: 037 | Q: CD | W: CD | E: CD | R: CD
# Video Time: 00:07:09.635 | Gold: 0551 | Minions: 037 | Q: 6 | W: CD | E: CD | R: 88
# Video Time: 00:07:10.595 | Gold: 0553 | Minions: 037 | Q: CD | W: CD | E: CD | R: 82
# Video Time: 00:07:11.569 | Gold: 0555 | Minions: 037 | Q: CD | W: CD | E: CD | R: CD
# Video Time: 00:07:12.556 | Gold: 0557 | Minions: 007 | Q: CD | W: CD | E: Ready | R: 80
# Video Time: 00:07:13.543 | Gold: 0559 | Minions: 037 | Q: CD | W: CD | E: Ready | R: CD
# Video Time: 00:07:14.530 | Gold: 0561 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:15.517 | Gold: 0562 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:16.504 | Gold: 0564 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: 7
# Video Time: 00:07:17.478 | Gold: 0566 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: 4
# Video Time: 00:07:18.478 | Gold: 0568 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:19.478 | Gold: 0570 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:20.479 | Gold: 0572 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: 4
# Video Time: 00:07:21.533 | Gold: 0575 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:22.506 | Gold: 0581 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:23.493 | Gold: 0583 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: 8
# Video Time: 00:07:24.480 | Gold: 0586 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:25.454 | Gold: 0583 | Minions: 037 | Q: Ready | W: CD | E: Ready | R: 7
# Video Time: 00:07:26.361 | Gold: 0615 | Minions: 038 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:27.335 | Gold: 0617 | Minions: 038 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:28.335 | Gold: 0619 | Minions: 038 | Q: Ready | W: CD | E: Ready | R: 6
# Video Time: 00:07:29.309 | Gold: 0621 | Minions: 038 | Q: CD | W: 22 | E: CD | R: 6
# Video Time: 00:07:30.309 | Gold: 0623 | Minions: 038 | Q: CD | W: 22 | E: Ready | R: 6
# Video Time: 00:07:31.269 | Gold: 0625 | Minions: 038 | Q: 6 | W: 2 | E: Ready | R: 6
# Video Time: 00:07:32.376 | Gold: 0627 | Minions: 038 | Q: CD | W: 19 | E: CD | R: CD
# Video Time: 00:07:33.390 | Gold: 0629 | Minions: 038 | Q: CD | W: 8 | E: 8 | R: 8
# Video Time: 00:07:34.364 | Gold: 0631 | Minions: 038 | Q: CD | W: 7 | E: CD | R: 58
# Video Time: 00:07:35.351 | Gold: 0654 | Minions: 039 | Q: CD | W: 16 | E: CD | R: 5
# Video Time: 00:07:36.325 | Gold: 0677 | Minions: 040 | Q: Ready | W: CD | E: CD | R: 56
# Video Time: 00:07:37.365 | Gold: 0679 | Minions: 040 | Q: Ready | W: 1 | E: CD | R: 55
# Video Time: 00:07:38.339 | Gold: 0681 | Minions: 040 | Q: Ready | W: CD | E: CD | R: 5
# Video Time: 00:07:39.339 | Gold: 0683 | Minions: 040 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:40.366 | Gold: 0699 | Minions: 041 | Q: Ready | W: CD | E: Ready | R: 2
# Video Time: 00:07:41.366 | Gold: 0701 | Minions: 041 | Q: CD | W: 18 | E: Ready | R: CD
# Video Time: 00:07:42.380 | Gold: 0703 | Minions: 001 | Q: CD | W: 9 | E: Ready | R: 58
# Video Time: 00:07:43.367 | Gold: 0705 | Minions: 000 | Q: CD | W: CD | E: Ready | R: CD
# Video Time: 00:07:44.354 | Gold: 0721 | Minions: 042 | Q: CD | W: CD | E: Ready | R: CD
# Video Time: 00:07:45.341 | Gold: 0723 | Minions: 042 | Q: CD | W: CD | E: Ready | R: CD
# Video Time: 00:07:46.342 | Gold: 0725 | Minions: 042 | Q: CD | W: CD | E: Ready | R: 48
# Video Time: 00:07:47.315 | Gold: 0727 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: 8
# Video Time: 00:07:48.342 | Gold: 0729 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: 6
# Video Time: 00:07:49.343 | Gold: 0732 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: 8
# Video Time: 00:07:50.356 | Gold: 0734 | Minions: 042 | Q: Ready | W: Ready | E: Ready | R: 2
# Video Time: 00:07:51.343 | Gold: 0736 | Minions: 042 | Q: Ready | W: Ready | E: Ready | R: CD
# Video Time: 00:07:52.357 | Gold: 0863 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:53.384 | Gold: 0865 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: 8
# Video Time: 00:07:54.384 | Gold: 0867 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: 8
# Video Time: 00:07:55.345 | Gold: 0869 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:56.358 | Gold: 0871 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:57.359 | Gold: 0873 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:58.346 | Gold: 0875 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:07:59.333 | Gold: 0877 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: 8
# Video Time: 00:08:00.347 | Gold: 0879 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: 2
# Video Time: 00:08:01.360 | Gold: 0881 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: 4
# Video Time: 00:08:02.347 | Gold: 0883 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:08:03.294 | Gold: 8385 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: 2
# Video Time: 00:08:04.295 | Gold: 0887 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:08:05.255 | Gold: 8389 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:08:06.269 | Gold: 0891 | Minions: 042 | Q: Ready | W: CD | E: CD | R: CD
# Video Time: 00:08:07.229 | Gold: 0893 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:08.216 | Gold: 0895 | Minions: 042 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:09.203 | Gold: 0939 | Minions: 045 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:08:10.163 | Gold: 0941 | Minions: 045 | Q: Ready | W: CD | E: 4 | R: Ready
# Video Time: 00:08:11.124 | Gold: 0964 | Minions: 046 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:08:12.111 | Gold: 0966 | Minions: 046 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:08:13.138 | Gold: 0968 | Minions: 046 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:08:14.152 | Gold: 0992 | Minions: 047 | Q: 8 | W: CD | E: CD | R: Ready
# Video Time: 00:08:15.205 | Gold: 0994 | Minions: 047 | Q: CD | W: CD | E: CD | R: Ready
# Video Time: 00:08:16.179 | Gold: 0996 | Minions: 047 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:08:17.193 | Gold: 0998 | Minions: 047 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:08:18.193 | Gold: 0000 | Minions: 047 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:08:19.207 | Gold: 1002 | Minions: 047 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:08:20.180 | Gold: 1004 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:21.141 | Gold: 1006 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:22.154 | Gold: 1008 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:23.182 | Gold: 1010 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:24.169 | Gold: 1012 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:25.182 | Gold: 1014 | Minions: 004 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:26.156 | Gold: 1016 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:27.156 | Gold: 1018 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:28.197 | Gold: 1020 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:29.184 | Gold: 1022 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:30.157 | Gold: 1024 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:31.171 | Gold: 1026 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:32.171 | Gold: 1028 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:33.198 | Gold: 1030 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:34.185 | Gold: 1032 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:35.199 | Gold: 1034 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:36.186 | Gold: 1036 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:37.200 | Gold: 1038 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:38.187 | Gold: 1040 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:39.161 | Gold: 41043 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:40.188 | Gold: 0195 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:41.215 | Gold: 0197 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:42.215 | Gold: 0199 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:43.242 | Gold: 0201 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:44.269 | Gold: 0203 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:45.310 | Gold: 0205 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:46.297 | Gold: 0207 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:47.324 | Gold: 0209 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:48.284 | Gold: 0211 | Minions: 047 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:08:49.284 | Gold: 0213 | Minions: 047 | Q: 6 | W: CD | E: Ready | R: Ready
# Video Time: 00:08:50.285 | Gold: 0215 | Minions: 047 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:08:51.312 | Gold: 0217 | Minions: 047 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:08:52.299 | Gold: 0219 | Minions: 047 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:08:53.339 | Gold: 0221 | Minions: 047 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:08:54.326 | Gold: 0223 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:55.366 | Gold: 0225 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:56.354 | Gold: 0227 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:57.327 | Gold: 0229 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:58.314 | Gold: 0231 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:08:59.288 | Gold: 0233 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:00.288 | Gold: 0235 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:01.289 | Gold: 0237 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:02.289 | Gold: 0239 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:03.276 | Gold: 0241 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:04.223 | Gold: 0244 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:05.210 | Gold: 0246 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:06.197 | Gold: 0248 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:07.171 | Gold: 0250 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:08.158 | Gold: 0252 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:09.131 | Gold: 0254 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:10.132 | Gold: 0256 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:11.105 | Gold: 0258 | Minions: 047 | Q: Ready | W: Ready | E: Ready | R: Ready
# Video Time: 00:09:12.106 | Gold: 0260 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:13.053 | Gold: 0261 | Minions: 047 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:14.067 | Gold: 0284 | Minions: 048 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:15.094 | Gold: 0315 | Minions: 050 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:16.161 | Gold: 0331 | Minions: 051 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:09:17.228 | Gold: 0333 | Minions: 051 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:09:18.228 | Gold: 0335 | Minions: 051 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:09:19.228 | Gold: 0337 | Minions: 001 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:09:20.215 | Gold: 0339 | Minions: 051 | Q: Ready | W: CD | E: 4 | R: Ready
# Video Time: 00:09:21.229 | Gold: 0341 | Minions: 051 | Q: CD | W: CD | E: CD | R: Ready
# Video Time: 00:09:22.216 | Gold: 0468 | Minions: 051 | Q: 7 | W: CD | E: Ready | R: Ready
# Video Time: 00:09:23.203 | Gold: 0470 | Minions: 051 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:09:24.244 | Gold: 0472 | Minions: 051 | Q: 7 | W: CD | E: Ready | R: Ready
# Video Time: 00:09:25.257 | Gold: 0474 | Minions: 051 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:09:26.271 | Gold: 0476 | Minions: 051 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:09:27.245 | Gold: 0478 | Minions: 001 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:28.272 | Gold: 0480 | Minions: 051 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:29.219 | Gold: 0483 | Minions: 051 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:30.192 | Gold: 0485 | Minions: 051 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:31.206 | Gold: 0487 | Minions: 051 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:32.260 | Gold: 0489 | Minions: 051 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:33.274 | Gold: 0491 | Minions: 001 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:34.274 | Gold: 0493 | Minions: 051 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:35.261 | Gold: 0495 | Minions: 051 | Q: Ready | W: CD | E: Ready | R: Ready
# Video Time: 00:09:36.275 | Gold: 0497 | Minions: 001 | Q: CD | W: CD | E: Ready | R: Ready
# Video Time: 00:09:37.222 | Gold: 0499 | Minions: 051 | Q: CD | W: 2 | E: Ready | R: Ready
# Video Time: 00:09:38.182 | Gold: 0536 | Minions: 053 | Q: 6 | W: 2 | E: Ready | R: Ready
# Video Time: 00:09:39.182 | Gold: 0559 | Minions: 054 | Q: CD | W: 20 | E: Ready | R: Ready
# Video Time: 00:09:40.223 | Gold: 0561 | Minions: 054 | Q: CD | W: 1 | E: 8 | R: Ready
# Video Time: 00:09:41.223 | Gold: 0563 | Minions: 054 | Q: CD | W: 18 | E: CD | R: Ready
# Video Time: 00:09:42.237 | Gold: 0565 | Minions: 054 | Q: CD | W: CD | E: CD | R: Ready
# Video Time: 00:09:43.224 | Gold: 0567 | Minions: 054 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:09:44.211 | Gold: 0569 | Minions: 054 | Q: Ready | W: CD | E: CD | R: Ready
# Video Time: 00:09:45.198 | Gold: 0828 | Minions: 054 | Q: CD | W: 1 | E: CD | R: 428
# Video Time: 00:09:46.238 | Gold: 0850 | Minions: 054 | Q: 6 | W: CD | E: Ready | R: CD
# Video Time: 00:09:47.212 | Gold: 0852 | Minions: 054 | Q: CD | W: CD | E: Ready | R: CD
# Video Time: 00:09:48.159 | Gold: 0854 | Minions: 054 | Q: CD | W: CD | E: Ready | R: 117
# Video Time: 00:09:49.186 | Gold: 0856 | Minions: 054 | Q: CD | W: CD | E: Ready | R: CD
# Video Time: 00:09:50.200 | Gold: 0858 | Minions: 005 | Q: CD | W: 9 | E: Ready | R: CD
# Video Time: 00:09:51.173 | Gold: 0860 | Minions: 054 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:09:52.160 | Gold: 0862 | Minions: 054 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:09:53.161 | Gold: 0864 | Minions: 054 | Q: Ready | W: CD | E: Ready | R: 2
# Video Time: 00:09:54.134 | Gold: 0867 | Minions: 054 | Q: Ready | W: CD | E: Ready | R: 11
# Video Time: 00:09:55.121 | Gold: 0869 | Minions: 054 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:09:56.148 | Gold: 0871 | Minions: 054 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:09:57.136 | Gold: 0873 | Minions: 054 | Q: Ready | W: Ready | E: Ready | R: 2
# Video Time: 00:09:58.163 | Gold: 0875 | Minions: 054 | Q: Ready | W: Ready | E: Ready | R: CD
# Video Time: 00:09:59.136 | Gold: 0877 | Minions: 054 | Q: Ready | W: CD | E: Ready | R: 8
# Video Time: 00:10:00.137 | Gold: 0879 | Minions: 054 | Q: Ready | W: CD | E: Ready | R: 88
# Video Time: 00:10:01.150 | Gold: 0881 | Minions: 054 | Q: Ready | W: CD | E: Ready | R: CD
# Video Time: 00:10:02.151 | Gold: 0883 | Minions: 054 | Q: Ready | W: CD | E: Ready | R: 82
# Video Time: 00:10:03.178 | Gold: 0885 | Minions: 054 | Q: CD | W: CD | E: Ready | R: 42
# Video Time: 00:10:04.138 | Gold: 0887 | Minions: 054 | Q: CD | W: CD | E: Ready | R: CD
# Video Time: 00:10:05.138 | Gold: 0889 | Minions: 054 | Q: CD | W: CD | E: Ready | R: 489
# Video Time: 00:10:06.099 | Gold: 0891 | Minions: 054 | Q: CD | W: CD | E: Ready | R: CD
# Video Time: 00:10:07.086 | Gold: 1318 | Minions: 054 | Q: CD | W: CD | E: Ready | R: 98
# Video Time: 00:10:08.086 | Gold: 1320 | Minions: 054 | Q: CD | W: CD | E: Ready | R: 98
# Video Time: 00:10:09.073 | Gold: 1322 | Minions: 054 | Q: Ready | W: CD | E: Ready | R: 97
# Processing completed. Results saved to extracted_frames_MR
